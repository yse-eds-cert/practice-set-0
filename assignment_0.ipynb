# %% [markdown]
# <a href="https://colab.research.google.com/github/yse-eds-cert/practice-set-0/blob/main/assignment_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Before you start — switch this notebook to the R runtime
#
# Google Colab defaults to a Python runtime. Because this problem set is written in R, you need to switch the runtime once before running any code:
#
# 1. In the Colab menu bar, click **Runtime → Change runtime type**.
# 2. Under **Runtime type**, select **R**.
# 3. Click **Save**. Colab will reload the notebook with R.
#
# You only need to do this once per Colab session. After switching, run the next cell to install the R packages you'll need.

# %% [markdown]
# # Assignment 0: Introduction to Google Colab & GitHub
#
# Welcome to the YSE Environmental Data Science Certificate Program! This assignment will walk you through:
#
# 1. Opening a notebook in Google Colab with an R kernel
# 2. Running R code in Colab
# 3. Saving your work back to GitHub
#
# ## Before you begin
#
# Complete this step **before** starting the exercises:
#
# 1. **File → Save a copy in Drive** — this creates an autosaving working copy in your Google Drive. Work from this copy so your progress is never lost.

# %% [markdown]
# ## Part 1: Check Your R Setup
#
# Run the cell below to confirm you are using an R kernel and check the R version.

# %%
# Check R version
R.version.string

# %% [markdown]
# ## Part 2: Basic R
#
# Run the cell below as-is, then answer the question underneath it.

# %%
# A simple calculation
x <- 5
y <- 3
x + y

# %% [markdown]
# **Question 1:** What did the cell above output? Does that match what you expected? *(Double-click this cell to edit and write your answer here.)*

# %% [markdown]
# ## Part 3: Your Turn
#
# In the cell below, write R code that creates a variable called `my_name` and assigns your name to it as a string. Then print it.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 4: Submit
#
# When you are finished with the exercises above, submit your work to GitHub:
#
# 1. Go to **File → Save a copy in GitHub** in the Colab menu.
# 2. Select your personal assignment repository (`yse-eds-cert/assignment-0-yourname`).
# 3. Click **OK** to commit your work.
#
# > **Tip:** Your Google Drive copy autosaves as you work. The GitHub save is your official submission — make sure to do this when you're done!
#
# Your assignment is submitted once your completed notebook appears in your GitHub repository. You're done! 🎉
